# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
import os

# %%
# Step 2: Define ETL Pipeline Functions
def extract_data(file_path: str) -> pd.DataFrame:
    """Extract data from a CSV file."""
    print("🔹 Extracting data from source...")
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")
    df = pd.read_csv(file_path)
    print(f"✅ Data extracted successfully! Shape: {df.shape}")
    return df


def transform_data(df: pd.DataFrame) -> pd.DataFrame:
    """Clean, transform, and prepare the data."""
    print("🔹 Transforming data...")
    # Handle missing values
    df.fillna(df.mean(numeric_only=True), inplace=True)
    # Encode categorical columns
    label_encoders = {}
    for col in df.select_dtypes(include=['object']).columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
        label_encoders[col] = le
    # Scale numerical columns
    scaler = StandardScaler()
    numerical_cols = df.select_dtypes(include=np.number).columns
    df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
    print("✅ Data transformed successfully!")
    return df


def load_data(df: pd.DataFrame, output_path: str):
    """Load the processed data to a new CSV file."""
    print("🔹 Loading data to destination...")
    df.to_csv(output_path, index=False)
    print(f"✅ Data loaded successfully to {output_path}")

# %%
# Step 3: Execute ETL Pipeline
input_file = '/tmp/input_data.csv'  # Replace with your input file path
output_file = '/tmp/output_data.csv' # Replace with your desired output file path

# Create a dummy input file for demonstration purposes
# In a real scenario, you would have your actual data file
dummy_data = {
    'col1': [1, 2, 3, 4, 5],
    'col2': ['A', 'B', 'A', 'C', 'B'],
    'col3': [10.5, 12.3, np.nan, 15.1, 11.8]
}
dummy_df = pd.DataFrame(dummy_data)
dummy_df.to_csv(input_file, index=False)
print(f"Created a dummy input file at: {input_file}")


# Execute the ETL pipeline
extracted_df = extract_data(input_file)
transformed_df = transform_data(extracted_df)
load_data(transformed_df, output_file)

print("\nETL Pipeline execution complete.")
# Out:
# Created a dummy input file at: /tmp/input_data.csv
# 🔹 Extracting data from source...
# ✅ Data extracted successfully! Shape: (5, 3)
# 🔹 Transforming data...
# ✅ Data transformed successfully!
# 🔹 Loading data to destination...
# ✅ Data loaded successfully to /tmp/output_data.csv
#
# ETL Pipeline execution complete.

# %%
# Main Pipeline Execution
def main():
    # File paths
    input_file = "raw_data.csv"     # Input dataset
    output_file = "processed_data.csv"  # Output file after ETL

    print("🚀 Starting ETL Data Pipeline...")

# %%
# ETL workflow
raw_df = extract_data(input_file)
transformed_df = transform_data(raw_df)
load_data(transformed_df, output_file)
print("ETL Pipeline executed successfully!")
# Out:
# 🔹 Extracting data from source...
# ✅ Data extracted successfully! Shape: (5, 3)
# 🔹 Transforming data...
# ✅ Data transformed successfully!
# 🔹 Loading data to destination...
# ✅ Data loaded successfully to /tmp/output_data.csv
# ETL Pipeline executed successfully!

# %%
# Run pipeline
if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting ETL Data Pipeline...

# %%
"raw_data.csv"
# Out:
# 'raw_data.csv'

# %%
"processed_data.csv"
# Out:
# 'processed_data.csv'
